# %% [markdown]
# ### To know mopre about this dataset please visit :
# https://www.drivendata.org/competitions/2/warm-up-predict-blood-donations/page/7/
#
#
# https://www.kaggle.com/datasets/bonastreyair/predicting-blood-analysis

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/Warm_Up_Predict_Blood_Donations_-_Traning_Data.csv')
data
# Out:
#      Unnamed: 0  Months since Last Donation  Number of Donations  \
# 0           619                           2                   50
# 1           664                           0                   13
# 2           441                           1                   16
# 3           160                           2                   20
# 4           358                           1                   24
# ..          ...                         ...                  ...
# 571         698                          23                    1
# 572         433                          16                    3
# 573         360                          21                    2
# 574         541                          39                    1
# 575          74                          72                    1
#
#      Total Volume Donated (c.c.)  Months since First Donation  \
# 0                          12500                           98
# ...
